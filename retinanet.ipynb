# %% [markdown]
# <a href="https://colab.research.google.com/github/hieubkset/prv_colab/blob/master/retinanet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %tensorflow_version 1.x

# %%
# !cp "/content/drive/My Drive/ship_detection_online.rar" .
# !unrar x ship_detection_online.rar
# !mkdir data
# !mv Annotations_new/ Annotations
# !mv Annotations data
# !mv JPEGImages data

# %%
import os

path = "/content/drive/My Drive/retinanet"
os.chdir(path)

# %%
# !pip install numpy --user
# !pip install . --user
# !python setup.py build_ext --inplace
# !cp -r "/content/drive/My Drive/retinanet/data/ImageSets" /content/data

# %%
# !python keras_retinanet/bin/train.py --weights snapshots/resnet50_pascal_20.h5 --steps 1000 --no-evaluation pascal /content/data
# Out:
# Using TensorFlow backend.
# 2020-05-13 18:06:57.086343: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-13 18:06:58.609252: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-13 18:06:58.630285: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-13 18:06:58.630842: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-05-13 18:06:58.630881: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...
